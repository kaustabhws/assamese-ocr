# %% [markdown]
# # 05 — Assamese page benchmark
#
# Use only manually checked Assamese pages here. Follow `docs/ANNOTATION.md`; keep each source document wholly inside one split. This notebook measures semantic layout, reading order, and end-to-end OCR rather than isolated word crops.

# %%
from pathlib import Path

GROUND_TRUTH = Path("data/processed/page_benchmark/test.json")
PREDICTION = Path("artifacts/page_benchmark/prediction.json")
assert GROUND_TRUTH.exists(), "Create the manually checked benchmark first"
assert PREDICTION.exists(), "Run end-to-end OCR on the same pages first"

# %%
# !python scripts/evaluate_document.py --ground-truth "{GROUND_TRUTH}" --prediction "{PREDICTION}" --output artifacts/page_evaluation.json

# %%
import json

report = json.loads(Path("artifacts/page_evaluation.json").read_text(encoding="utf-8"))
print(json.dumps(report, ensure_ascii=False, indent=2))
